# %%
import pandas as pd

data = pd.read_csv("merge_data.csv",low_memory=False)
data.head(20)
pd.set_option('display.max_rows', 215)

# %%
data.shape
# Out:
# (3292, 2115)

# %%
data = data.T.drop_duplicates().T

# %%
data.shape
# Out:
# (3292, 1998)

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (3292, 1998)

# %%
states = [
    "Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware", "Florida",
    "Georgia", "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana", "Maine",
    "Maryland", "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana", "Nebraska",
    "Nevada", "New Hampshire", "New Jersey", "New Mexico", "New York", "North Carolina", "North Dakota", "Ohio",
    "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island", "South Carolina", "South Dakota", "Tennessee", "Texas",
    "Utah", "Vermont", "Virginia", "Washington", "West Virginia", "Wisconsin", "Wyoming"
]

# Convert list to uppercase for case-insensitive matching
states_upper = [state.upper() for state in states]

# Filter out rows containing only state names
only_state_df = data[~data["statecounty_x"].str.upper().str.contains('|'.join(states_upper), na=False)]
only_state_df
# Out:
#                                        statecounty_x  \
# 0                                          01Autauga
# 1                                          01Baldwin
# 2                                          01Barbour
# 3                                             01Bibb
# 4                                           01Blount
# ...                                              ...
# 3287                                          66Guam
# 3288  69Commonwealth of the Northern Mariana Islands
# 3289                                   72Puerto Rico
# 3290                   74U.S. Minor Outlying Islands
# 3291                  78United States Virgin Islands
#
#      Highest_PM2.5_Concentration_microgram/m^3_of_Annual_Average_EPA2016  \
# 0                                                   NaN
# 1                                                   7.2
# 2                                                   NaN
# 3                                                   NaN
# ...

# %%
data.tail(200)
# Out:
#                                        statecounty_x  \
# 3092                                     55Outagamie
# 3093                                       55Ozaukee
# 3094                                         55Pepin
# 3095                                        55Pierce
# 3096                                          55Polk
# 3097                                       55Portage
# 3098                                         55Price
# 3099                                        55Racine
# 3100                                      55Richland
# 3101                                          55Rock
# 3102                                          55Rusk
# 3103                                     55St. Croix
# 3104                                          55Sauk
# 3105                                        55Sawyer
# 3106                                       55Shawano
# 3107                                     55Sheboygan
# 3108                                        55Taylor
# ...

# %%
data = data[0:3143]

# %%
data.shape
# Out:
# (3143, 1998)

# %%
data.to_csv("orginal_data.csv", index=False)

# %%
data = pd.read_csv("orginal_data.csv", low_memory = False)

# %%
location = pd.read_csv("location.csv")

# %%
location = location.sort_values(by='NAME').reset_index(drop=True)

# %%
data["statecounty_x"] = data["statecounty_x"].str.lower()

# %%
data.head(20)
# Out:
#    statecounty_x  \
# 0        autauga
# 1        baldwin
# 2        barbour
# 3           bibb
# 4         blount
# 5        bullock
# 6         butler
# 7        calhoun
# 8       chambers
# 9       cherokee
# 10       chilton
# 11       choctaw
# 12        clarke
# 13          clay
# 14      cleburne
# 15        coffee
# 16       colbert
# 17       conecuh
# 18         coosa
# 19     covington
#
#     Highest_PM2.5_Concentration_microgram/m^3_of_Annual_Average_EPA2016  \
# 0                                                 NaN
# 1                                                 7.2
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# ...

# %%
location
# Out:
#       OBJECTID  STATEFP  COUNTYFP  COUNTYNS  GEOID         GEOIDFQ       NAME  \
# 0         2212       45         1   1245666  45001  0500000US45001  abbeville
# 1         3047       22         1    558389  22001  0500000US22001     acadia
# 2         1991       51         1   1480091  51001  0500000US51001   accomack
# 3         1683       16         1    395066  16001  0500000US16001        ada
# 4          236       21         1    516847  21001  0500000US21001      adair
# ...        ...      ...       ...       ...    ...             ...        ...
# 3141      2321        8       125    198178   8125  0500000US08125       yuma
# 3142       398        4        27     23901   4027  0500000US04027       yuma
# 3143      3185       48       505   1384038  48505  0500000US48505     zapata
# 3144       280       48       507   1384039  48507  0500000US48507     zavala
# 3145       504       46       137   1266993  46137  0500000US46137    ziebach
#
# ...

# %%
data['county_name'] = data['statecounty_x']
location['NAME'] = location['NAME']
merged_data = pd.merge(data, location[['NAME', 'INTPTLAT', 'INTPTLON']], 
                       left_on='county_name', right_on='NAME', how='left')

merged_data = merged_data.drop(columns=['NAME', 'county_name'])
merged_data
# Out:
#       statecounty_x  \
# 0           autauga
# 1           baldwin
# 2           baldwin
# 3           barbour
# 4           barbour
# ...             ...
# 14790         teton
# 14791         teton
# 14792         uinta
# 14793      washakie
# 14794        weston
#
#        Highest_PM2.5_Concentration_microgram/m^3_of_Annual_Average_EPA2016  \
# 0                                                    NaN
# 1                                                    7.2
# 2                                                    7.2
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14790                                                4.4
# 14791                                                4.4
# 14792                                                NaN
# 14793                                                NaN
# 14794                                                2.9
#
# ...

# %%
# Out:
#       statecounty_x  \
# 0           Autauga
# 9           Bullock
# 39          Chilton
# 71          Colbert
# 72          Conecuh
# ...             ...
# 14787      Sublette
# 14788    Sweetwater
# 14792         Uinta
# 14793      Washakie
# 14794        Weston
#
#        Highest_PM2.5_Concentration_microgram/m^3_of_Annual_Average_EPA2016  \
# 0                                                    NaN
# 9                                                    NaN
# 39                                                   NaN
# 71                                                   7.5
# 72                                                   NaN
# ...                                                  ...
# 14787                                                4.6
# 14788                                                5.0
# 14792                                                NaN
# 14793                                                NaN
# 14794                                                2.9
#
# ...
