# %%
import pandas as pd
data = pd.read_csv("three_data_merged.csv")
# Out:
# /var/folders/26/l89mqgp17zj82yvlmd3z3r200000ks/T/ipykernel_97377/776332092.py:2: DtypeWarning: Columns (249,250,255,256,257,258,259,264,265,266,267,278,279,280,281,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,297,308,309,315,316,317,318,319,321,325,326,327,338,339,344,345,346,347,348,349,350,351,354,355,356,357,368,369,372,373,374,377,385,386,387,388,389,390,391,393,394,2060,2061) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("three_data_merged.csv")

# %%
data
# Out:
#      statecounty_x  \
# 0        01autauga
# 1        01baldwin
# 2        01barbour
# 3           01bibb
# 4         01blount
# ...            ...
# 3138  56sweetwater
# 3139       56teton
# 3140       56uinta
# 3141    56washakie
# 3142      56weston
#
#       Highest_PM2.5_Concentration_microgram/m^3_of_Annual_Average_EPA2016  \
# 0                                                   NaN
# 1                                                   7.2
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3138                                                5.0
# 3139                                                4.4
# 3140                                                NaN
# 3141                                                NaN
# 3142                                                2.9
#
# ...
