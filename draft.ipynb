# %%
import pandas as pd
data = pd.read_csv('single_merged+geo.csv')
data2 = pd.read_csv('raw.csv')
data3 = pd.read_csv('merged_output.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 data = pd.read_csv('single_merged+geo.csv')
# ----> 3 data2 = pd.read_csv('raw.csv')
#       4 data3 = pd.read_csv('merged_output.csv')
#
# ...

# %%
data
# Out:
#               statecounty  Total_Violent_and_Property_Crimes_FBI2019  \
# 0        01Autauga County                                        NaN
# 1        01Baldwin County                                        NaN
# 2        01Barbour County                                        NaN
# 3           01Bibb County                                        NaN
# 4         01Blount County                                        NaN
# ...                   ...                                        ...
# 3137    56Sublette County                                       48.0
# 3138  56Sweetwater County                                       99.0
# 3139       56Teton County                                        NaN
# 3140       56Uinta County                                       42.0
# 3141    56Washakie County                                       24.0
#
#       Total_Violent_and_Property_Crimes_Rate_FBI2019  \
# 0                                                NaN
# ...

# %%
data3
# Out:
#               statecounty  Total_Violent_and_Property_Crimes_FBI2019  \
# 0        01Autauga County                                        NaN
# 1        01Baldwin County                                        NaN
# 2        01Barbour County                                        NaN
# 3           01Bibb County                                        NaN
# 4         01Blount County                                        NaN
# ...                   ...                                        ...
# 3137    56Sublette County                                       48.0
# 3138  56Sweetwater County                                       99.0
# 3139       56Teton County                                        NaN
# 3140       56Uinta County                                       42.0
# 3141    56Washakie County                                       24.0
#
#       Total_Violent_and_Property_Crimes_Rate_FBI2019  \
# 0                                                NaN
# ...

# %%
data2
# Out:
#               statecounty  Total_Violent_and_Property_Crimes_FBI2019  \
# 0        01Autauga County                                        NaN
# 1        01Baldwin County                                        NaN
# 2        01Barbour County                                        NaN
# 3           01Bibb County                                        NaN
# 4         01Blount County                                        NaN
# ...                   ...                                        ...
# 3137    56Sublette County                                       48.0
# 3138  56Sweetwater County                                       99.0
# 3139       56Teton County                                        NaN
# 3140       56Uinta County                                       42.0
# 3141    56Washakie County                                       24.0
#
#       Total_Violent_and_Property_Crimes_Rate_FBI2019  \
# 0                                                NaN
# ...

# %%
data = pd.read_csv('cvrm_master.csv')
data.select_dtypes(exclude='number')
# Out:
# /var/folders/26/l89mqgp17zj82yvlmd3z3r200000ks/T/ipykernel_85488/1180920965.py:1: DtypeWarning: Columns (1697,1698) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('cvrm_master.csv')
#      statecounty_x  mapped_match   stname        name          Code State  \
# 0        01autauga     01autauga  Alabama     Autauga     01autauga    AL
# 1        01baldwin     01baldwin  Alabama     Baldwin     01baldwin    AL
# 2        01barbour     01barbour  Alabama     Barbour     01barbour    AL
# 3           01bibb        01bibb  Alabama        Bibb        01bibb    AL
# 4         01blount      01blount  Alabama      Blount      01blount    AL
# ...            ...           ...      ...         ...           ...   ...
# 3138  56sweetwater  56sweetwater  Wyoming  Sweetwater  56sweetwater    WY
# 3139       56teton       56teton  Wyoming       Teton       56teton    WY
# 3140       56uinta       56uinta  Wyoming       Uinta       56uinta    WY
# ...
